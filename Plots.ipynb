# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})

# %%
First_Method = {"Iterations": [1, 5, 10, 30, 55, 63]
                ,"Time": [3780397, 4802439, 6347168, 12690913, 25331975, 30714843]
                ,"Loss": [0.974253, 0.00276032, 1.50E-04, 8.06E-07, 6.01E-13, 3.18E-24]}	

Second_Method = {"Iterations": [1, 5, 15, 50, 95, 150, 300]
                ,"Time": [1993526, 2691859, 4436826, 121493525, 281173254, 498346972, 1008679164]
                ,"Loss": [0.972018, 0.00270776, 1.45E-04, 9.65E-05, 9.65E-05, 9.65E-05, 9.65E-05]}	

Third_Method = {"Iterations": [1, 5, 15, 50, 95, 150, 300]
                ,"Time": [2061238, 2840865, 26213925, 77535939, 227809247, 436014742, 989833579]
                ,"Loss": [0.972038, 0.0026592, 1.51E-04, 3.11E-05, 6.03E-06, 6.03E-06, 6.03E-06]}

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(First_Method["Time"], First_Method["Loss"], color = "green", label = "First Method\n(number of iterations)", marker = "o", markerfacecolor = "green", markersize = 9)

for i, txt in enumerate(First_Method["Iterations"]):

    plt.annotate(txt, (First_Method["Time"][i], First_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig1.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(Second_Method["Time"], Second_Method["Loss"], color = "blue", label = "Second Method\n(number of iterations)", marker = "o", markerfacecolor = "blue", markersize = 9)

for i, txt in enumerate(Second_Method["Iterations"]):

    plt.annotate(txt, (Second_Method["Time"][i], Second_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig2.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(Third_Method["Time"], Third_Method["Loss"], color = "black", label = "Third Method\n(number of iterations)", marker = "o", markerfacecolor = "black", markersize = 9)

for i, txt in enumerate(Third_Method["Iterations"]):

    plt.annotate(txt, (Third_Method["Time"][i], Third_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig3.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
First_Method = {"Iterations": [5, 10, 30, 55, 63]
                ,"Time": [4802439, 6347168, 12690913, 25331975, 30714843]
                ,"Loss": [0.00276032, 1.50E-04, 8.06E-07, 6.01E-13, 3.18E-24]}	

Second_Method = {"Iterations": [5, 15, 50, 95, 150, 300]
                ,"Time": [2691859, 4436826, 121493525, 281173254, 498346972, 1008679164]
                ,"Loss": [0.00270776, 1.45E-04, 9.65E-05, 9.65E-05, 9.65E-05, 9.65E-05]}	

Third_Method = {"Iterations": [5, 15, 50, 95, 150, 300]
                ,"Time": [2840865, 26213925, 77535939, 227809247, 436014742, 989833579]
                ,"Loss": [0.0026592, 1.51E-04, 3.11E-05, 6.03E-06, 6.03E-06, 6.03E-06]}

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(First_Method["Time"], First_Method["Loss"], color = "green", label = "First Method\n(number of iterations)", marker = "o", markerfacecolor = "green", markersize = 9)

for i, txt in enumerate(First_Method["Iterations"]):

    plt.annotate(txt, (First_Method["Time"][i], First_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig4.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(Second_Method["Time"], Second_Method["Loss"], color = "blue", label = "Second Method\n(number of iterations)", marker = "o", markerfacecolor = "blue", markersize = 9)

for i, txt in enumerate(Second_Method["Iterations"]):

    plt.annotate(txt, (Second_Method["Time"][i], Second_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig5.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize = (10, 10)); plt.yscale('log'); plt.xscale('log')

plt.plot(Third_Method["Time"], Third_Method["Loss"], color = "black", label = "Third Method\n(number of iterations)", marker = "o", markerfacecolor = "black", markersize = 9)

for i, txt in enumerate(Third_Method["Iterations"]):

    plt.annotate(txt, (Third_Method["Time"][i], Third_Method["Loss"][i]), fontsize=20)

plt.xlabel("Time of Execution (microseconds)", fontsize=20); plt.ylabel("Loss (value of function G)", fontsize=20)

plt.legend(prop={'size':20})

plt.savefig(".\img\Fig6.eps", format = "eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
